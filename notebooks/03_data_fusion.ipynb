# %% [markdown]
# # 03 - Data Fusion
#
# **CA683 - Traffic Congestion Prediction**
#
# Merge traffic, weather, and events data into a unified dataset.
#
# ## Objectives
# - Load cleaned data
# - Align temporal resolutions
# - Merge traffic + weather on timestamps
# - Add events proximity features
# - Create final unified dataset

# %%
# Import libraries
import pandas as pd
import numpy as np
from pathlib import Path
import sys
sys.path.append('../src')
print("✓ Ready for fusion")

# %% [markdown]
# ## 1. Load Cleaned Data

# %%
# Load cleaned datasets
data_dir = Path('../data/processed')

traffic = pd.read_csv(data_dir / 'traffic_cleaned.csv')
weather = pd.read_csv(data_dir / 'weather_cleaned.csv', parse_dates=['datetime'])
events = pd.read_csv(data_dir / 'events_cleaned.csv', parse_dates=['start_datetime', 'end_datetime'])

print(f"Traffic: {traffic.shape}")
print(f"Weather: {weather.shape}")
print(f"Events: {events.shape}")

# %% [markdown]
# ## 2. TODO: Implement Fusion Logic
#
# Key steps:
# 1. Parse and align timestamps
# 2. Merge traffic + weather on hourly basis
# 3. Add event proximity features
# 4. Save merged dataset
#
# **Note**: This requires understanding traffic data structure first.
# Run notebooks 01 and 02 to explore data before implementing fusion.

# %% [markdown]
# ## Next Steps
#
# After fusion is complete:
# - Proceed to `04_feature_engineering.ipynb`
